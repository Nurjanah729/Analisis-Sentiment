# %% [markdown]
# ## **Import LIbrary**

# %%
# !pip install google-play-scraper

# Mengimpor pustaka google-play scrapper untuk akses ulasan dan infrmasi aplikasi
from google_play_scraper import app, Sort, reviews_all

import pandas as pd
import numpy as np
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## **Scraping Dataset**

# %%
scrapereview = reviews_all(
    'com.discord',  # ID aplikasi
    lang='id',     # bahasa ulasan
    country='id',
    sort=Sort.MOST_RELEVANT,  # Urutan ulasan default sort.most_relevant
    count=3000     # jumlah maksimum ulasan yang diambil
)

# %% [markdown]
# ## **Save to CSV**

# %%
discord = pd.DataFrame(scrapereview)
discord.to_csv('discord_data.csv', index=False)

# %%
discord
# Out:
#                                    reviewId         userName  \
# 0      dffb5dc1-0e52-48ab-9166-069c0075adcb  Pengguna Google
# 1      b0db1c89-e03d-40b3-a905-80bf1856ad86  Pengguna Google
# 2      11806425-1efd-4afe-9596-a6f55a8d88fe  Pengguna Google
# 3      8c580c2a-2a1a-423f-9bdb-9fe5d93ccff5  Pengguna Google
# 4      b7a0089c-c6e0-4326-bbe9-ba9176ff0c9c  Pengguna Google
# ...                                     ...              ...
# 44995  8c8b333d-b5cd-4e29-97b2-c06864d2359d  Pengguna Google
# 44996  568a8b65-778f-43a5-94de-e0a4b33cbf1c  Pengguna Google
# 44997  8aa04998-44ae-41a1-be3a-ff5f798c0600  Pengguna Google
# 44998  616982fd-541c-4550-940f-54561c4abd0d  Pengguna Google
# 44999  de242538-924d-4641-a3e3-66c6bda2126c  Pengguna Google
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/EGemoI2N...
# 1      https://play-lh.googleusercontent.com/EGemoI2N...
# 2      https://play-lh.googleusercontent.com/EGemoI2N...
# ...
